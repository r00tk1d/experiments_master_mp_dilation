# %%
import matplotlib.pyplot as plt

# Results are from the following notebooks:
# results/segmentation/competitor_evaluation_known_fixed_m_specific_data_characteristics.ipynb
# results/segmentation/competitor_evaluation_known_fixed_target_w_specific_data_characteristics.ipynb

# %% [markdown]
# ## Window Size vs. Dilation Size ##

# %%
plt.rcParams.update({'font.size': 18})
fontsize = 18
dilation_sizes = [1,2,3,4,5]

# fixed w, mean, window sizes
w_mean_score_window_1 = [70.47, 70.17, 62.25, 57.47, 60.84]
w_mean_score_window_2 = [71.18, 71.06, 69.72, 65.18, 64.88]
w_mean_score_window_3 = [77.72, 63.28, 74.47, 73.29, 65.63]
plt.plot(dilation_sizes, w_mean_score_window_1, label='window coverage 10')
plt.plot(dilation_sizes, w_mean_score_window_2, label='window coverage 20')
plt.plot(dilation_sizes, w_mean_score_window_3, label='window coverage 50')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Mean Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
# place legend beside the graph
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed w, median, window sizes
w_median_score_window_1 = [67.97, 67.93, 57.32, 58.12, 57.23]
w_median_score_window_2 = [72.6, 84.79, 85.36, 57.02, 58.3]
w_median_score_window_3 = [78.6, 77.53, 75.45, 76.19, 64.39]
plt.plot(dilation_sizes, w_median_score_window_1, label='window coverage 10')
plt.plot(dilation_sizes, w_median_score_window_2, label='window coverage 20')
plt.plot(dilation_sizes, w_median_score_window_3, label='window coverage 50')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Median Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed m, mean, window sizes
m_mean_score_window_1 = [70.47, 71.51, 71.31, 68.4, 69.8]
m_mean_score_window_2 = [71.18, 72.09, 66.86, 66.0, 63.36]
m_mean_score_window_3 = [77.72, 78.06, 74.54, 60.74, 59.78]

plt.plot(dilation_sizes, m_mean_score_window_1, label='window size 10')
plt.plot(dilation_sizes, m_mean_score_window_2, label='window size 20')
plt.plot(dilation_sizes, m_mean_score_window_3, label='window size 50')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Mean Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed m, median, window sizes
m_median_score_window_1 = [67.97, 66.45, 67.0, 61.64, 73.93]
m_median_score_window_2 = [72.6, 80.56, 59.27, 59.01, 49.0]
m_median_score_window_3 = [78.6, 77.33, 71.61, 58.05, 57.45]
plt.plot(dilation_sizes, m_median_score_window_1, label='window size 10')
plt.plot(dilation_sizes, m_median_score_window_2, label='window size 20')
plt.plot(dilation_sizes, m_median_score_window_3, label='window size 50')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Median Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# ## Number of CPs vs. Dilation Size ##

# %%
plt.rcParams.update({'font.size': 18})
fontsize = 18
dilation_sizes = [1,2,3,4,5]

# fixed w, mean
w_mean_score_cp_1 = [85.57, 84.12, 77.6, 72.7, 71.37]
w_mean_score_cp_2 = [78.63, 77.34, 70.93, 70.79, 65.77]
w_mean_score_cp_3 = [64.02, 68.68, 63.74, 61.7, 66.49]
w_mean_score_cp_4 = [63.00, 60.07, 51.16, 46.56, 52.39]
plt.plot(dilation_sizes, w_mean_score_cp_1, label='1 CP')
plt.plot(dilation_sizes, w_mean_score_cp_2, label='2 CPs')
plt.plot(dilation_sizes, w_mean_score_cp_3, label='3 CPs')
plt.plot(dilation_sizes, w_mean_score_cp_4, label='4 CPs')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Mean Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed w, median
w_median_score_cp_1 = [96.99, 93.76, 91.88, 75.83, 71.45]
w_median_score_cp_2 = [74.53, 74.48, 66.08, 66.16, 64.39]
w_median_score_cp_3 = [56.37, 61.69, 56.33, 55.71, 57.23]
w_median_score_cp_4 = [58.8, 58.28, 40.37, 39.23, 47.99]
plt.plot(dilation_sizes, w_median_score_cp_1, label='1 CP')
plt.plot(dilation_sizes, w_median_score_cp_2, label='2 CPs')
plt.plot(dilation_sizes, w_median_score_cp_3, label='3 CPs')
plt.plot(dilation_sizes, w_median_score_cp_4, label='4 CPs')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Median Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed m, mean
m_mean_score_cp_1 = [85.57, 91.04, 85.87, 77.19, 76.72]
m_mean_score_cp_2 = [78.63, 75.12, 75.03, 75.1, 72.69]
m_mean_score_cp_3 = [64.02, 63.38, 60.61, 62.02, 67.10]
m_mean_score_cp_4 = [63.0, 60.09, 62.04, 55.25, 56.8]

plt.plot(dilation_sizes, m_mean_score_cp_1, label='1 CP')
plt.plot(dilation_sizes, m_mean_score_cp_2, label='2 CPs')
plt.plot(dilation_sizes, m_mean_score_cp_3, label='3 CPs')
plt.plot(dilation_sizes, m_mean_score_cp_4, label='4 CPs')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Mean Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed m, median
m_median_score_cp_1 = [96.99, 95.92, 95.17, 92.03, 90.62]
m_median_score_cp_2 = [74.53, 72.29, 68.11, 66.72, 69.49]
m_median_score_cp_3 = [56.37, 56.51, 56.32, 56.51, 73.93]
m_median_score_cp_4 = [58.8, 57.05, 58.99, 54.83, 57.66]
plt.plot(dilation_sizes, m_median_score_cp_1, label='1 CP')
plt.plot(dilation_sizes, m_median_score_cp_2, label='2 CPs')
plt.plot(dilation_sizes, m_median_score_cp_3, label='3 CPs')
plt.plot(dilation_sizes, m_median_score_cp_4, label='4 CPs')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Median Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# ## Time Series Length vs. Dilation Size ##

# %%
plt.rcParams.update({'font.size': 18})
fontsize = 18
dilation_sizes = [1,2,3,4,5]

# fixed w, mean
w_mean_score_tsl_1 = [84.2, 86.77, 82.26, 76.23, 73.72]
w_mean_score_tsl_2 = [77.64, 71.28, 65.74, 60.22, 62.8,]
w_mean_score_tsl_3 = [67.12, 70.93, 63.81, 63.59, 65.7]
w_mean_score_tsl_4 = [51.26, 44.87, 40.77, 38.95, 38.98]
plt.plot(dilation_sizes, w_mean_score_tsl_1, label='ts length [240, 2000)')
plt.plot(dilation_sizes, w_mean_score_tsl_2, label='ts length [2000, 4000)')
plt.plot(dilation_sizes, w_mean_score_tsl_3, label='ts length [4000, 8000)')
plt.plot(dilation_sizes, w_mean_score_tsl_4, label='ts length [8000, 20700]')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Mean Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed w, median
w_median_score_tsl_1 = [96.37, 96.97, 93.56, 83.92, 80.81]
w_median_score_tsl_2 = [78.67, 68.8, 62.38, 58.49, 57.36]
w_median_score_tsl_3 = [64.37, 67.93, 61.65, 61.77, 61.64]
w_median_score_tsl_4 = [41.44, 47.99, 41.47, 33.75, 40.81]
plt.plot(dilation_sizes, w_median_score_tsl_1, label='ts length [240, 2000)')
plt.plot(dilation_sizes, w_median_score_tsl_2, label='ts length [2000, 4000)')
plt.plot(dilation_sizes, w_median_score_tsl_3, label='ts length [4000, 8000)')
plt.plot(dilation_sizes, w_median_score_tsl_4, label='ts length [8000, 20700]')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Median Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed m, mean
m_mean_score_tsl_1 = [84.2, 83.79, 80.46, 75.02, 77.75]
m_mean_score_tsl_2 = [77.64, 78.34, 76.99, 73.06, 74.08]
m_mean_score_tsl_3 = [67.12, 68.13, 65.67, 64.2, 63.53]
m_mean_score_tsl_4 = [51.26, 51.99, 53.03, 48.35, 45.24]

plt.plot(dilation_sizes, m_mean_score_tsl_1, label='ts length [240, 2000)')
plt.plot(dilation_sizes, m_mean_score_tsl_2, label='ts length [2000, 4000)')
plt.plot(dilation_sizes, m_mean_score_tsl_3, label='ts length [4000, 8000)')
plt.plot(dilation_sizes, m_mean_score_tsl_4, label='ts length [8000, 20700]')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Mean Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# fixed m, median
m_median_score_tsl_1 = [96.37, 94.68, 92.03, 87.37, 89.68]
m_median_score_tsl_2 = [78.67, 85.35, 77.61, 76.73, 77.18]
m_median_score_tsl_3 = [64.37, 64.33, 59.29, 58.15, 57.87]
m_median_score_tsl_4 = [41.44, 42.89, 46.63, 42.77, 45.91]
plt.plot(dilation_sizes, m_median_score_tsl_1, label='ts length [240, 2000)')
plt.plot(dilation_sizes, m_median_score_tsl_2, label='ts length [2000, 4000)')
plt.plot(dilation_sizes, m_median_score_tsl_3, label='ts length [4000, 8000)')
plt.plot(dilation_sizes, m_median_score_tsl_4, label='ts length [8000, 20700]')
plt.xlabel('Dilation size', fontsize=fontsize)
plt.ylabel('Median Covering score', fontsize=fontsize)
plt.xticks(dilation_sizes)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
