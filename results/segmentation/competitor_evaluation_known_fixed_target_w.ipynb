# %% [markdown]
# # Evaluation of the Results for known CPs with fixed target range w #
# Notebook from https://github.com/ermshaua/time-series-segmentation-benchmark/blob/main/tssb/notebooks/competitor_evaluation.ipynb. Slightly edited.

# %%
import numpy as np
import pandas as pd

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import sys
sys.path.append("../../")

import orange3score

# %% [markdown]
# Let's load the scores from the different methods.

# %%
df_scores = pd.read_csv("./segmentation_covering_known_stumpy_target_w_ensemble.csv")
df_scores
# Out:
#                            dataset  flussEnsDil    fluss1    fluss2    fluss3  \
# 0                            Adiac     0.822399  0.970755  0.819214  0.822399
# 1                        ArrowHead     0.975078  0.994702  0.975078  0.866742
# 2                             Beef     0.939422  0.935417  0.936750  0.939422
# 3                        BeetleFly     0.655374  0.967709  0.645388  0.655374
# 4                      BirdChicken     0.477778  0.477703  0.477703  0.477703
# 5                              CBF     0.750326  0.764311  0.750326  0.749806
# 6                              Car     0.957359  0.939744  0.945569  0.957359
# 7                        Chinatown     1.000000  1.000000  1.000000  1.000000
# 8            ChlorineConcentration     0.937560  0.999744  0.937560  0.578968
# 9                     CinCECGTorso     0.851900  0.675982  0.851900  0.641094
# 10                          Coffee     0.992032  0.988071  0.988071  0.992032
# 11                       Computers     0.489950  0.493516  0.487437  0.489506
# 12                        CricketX     0.708784  0.787400  0.583241  0.403733
# 13                        CricketY     0.592347  0.563786  0.569219  0.566397
# 14                        CricketZ     0.616163  0.733173  0.616163  0.346579
# 15                            Crop     0.244522  0.247633  0.243803  0.244522
# 16             DiatomSizeReduction     0.969653  0.963736  0.969653  0.965233
# 17    DistalPhalanxOutlineAgeGroup     0.935578  0.934235  0.935578  0.935578
# 18                 DistalPhalanxTW     0.745654  0.745266  0.744763  0.745654
# 19                   DodgerLoopDay     1.000000  1.000000  1.000000  1.000000
# 20                          ECG200     0.992520  0.967874  0.967874  0.967874
# 21                     ECGFiveDays     0.987315  0.969889  0.969889  0.987315
# 22             EOGHorizontalSignal     0.408406  0.407675  0.408406  0.406033
# 23               EOGVerticalSignal     0.169664  0.340074  0.169664  0.169664
# 24                         FaceAll     0.401397  0.399217  0.401397  0.160531
# 25                        FaceFour     0.795838  0.795087  0.795683  0.794636
# 26                        FacesUCR     0.503539  0.652956  0.503539  0.302098
# 27                      FiftyWords     0.571413  0.571349  0.571413  0.563268
# 28                            Fish     0.367178  0.288193  0.363661  0.367178
# 29             FreezerRegularTrain     0.517146  0.519049  0.517146  0.515812
# 30                        GunPoint     0.250529  0.250529  0.250529  0.250529
# 31                             Ham     1.000000  1.000000  1.000000  1.000000
# 32                         Haptics     0.995743  0.988332  0.993621  0.995743
# 33                         Herring     0.669418  0.379821  0.348421  0.669418
# 34                     InlineSkate     0.672312  0.579493  0.597988  0.533672
# 35             InsectWingbeatSound     0.701601  0.689978  0.701601  0.489659
# 36                ItalyPowerDemand     0.991332  0.975431  0.974218  0.962169
# 37          LargeKitchenAppliances     0.964806  0.923315  0.546649  0.433951
# 38                      Lightning2     0.994984  0.687639  0.994984  0.960387
# 39                      Lightning7     0.775290  0.765345  0.775290  0.754501
# 40                          Mallat     0.573175  0.563681  0.560532  0.573175
# 41                            Meat     0.989350  0.990527  0.989350  0.648812
# 42                   MedicalImages     0.973891  0.991970  0.929810  0.973891
# 43             MelbournePedestrian     0.397400  0.399149  0.386825  0.397400
# 44    MiddlePhalanxOutlineAgeGroup     0.482822  0.331050  0.479932  0.482822
# 45     MiddlePhalanxOutlineCorrect     0.617674  0.616746  0.616863  0.616511
# 46                 MiddlePhalanxTW     1.000000  1.000000  1.000000  1.000000
# 47                      MoteStrain     0.920975  0.923184  0.912182  0.918770
# 48      NonInvasiveFetalECGThorax1     0.337453  0.335010  0.335269  0.335311
# 49      NonInvasiveFetalECGThorax2     0.414731  0.414358  0.414713  0.414731
# 50                         OSULeaf     0.731385  0.729270  0.731303  0.731159
# 51                        OliveOil     0.729142  0.718563  0.729142  0.645897
# 52                           Plane     0.721351  0.871782  0.721351  0.447074
# 53  ProximalPhalanxOutlineAgeGroup     0.686681  0.679707  0.679341  0.660802
# 54   ProximalPhalanxOutlineCorrect     0.548589  0.548578  0.548463  0.548589
# 55               ProximalPhalanxTW     0.846842  0.496142  0.846842  0.497254
# 56                     ShapeletSim     0.580513  0.785981  0.378988  0.580513
# 57                       ShapesAll     1.000000  1.000000  1.000000  1.000000
# 58           SonyAIBORobotSurface1     0.982961  0.973115  0.970315  0.982961
# 59           SonyAIBORobotSurface2     0.880012  0.985277  0.837189  0.498529
# 60                      Strawberry     0.798308  0.470744  0.472533  0.450605
# 61                     SwedishLeaf     0.983202  0.500668  0.983202  0.495117
# 62                         Symbols     0.830111  0.512736  0.514013  0.830111
# 63                SyntheticControl     0.582792  0.579710  0.582792  0.394099
# 64                ToeSegmentation1     0.997116  0.993523  0.997116  0.884613
# 65                ToeSegmentation2     0.994829  0.989684  0.989043  0.994829
# 66                           Trace     0.643909  0.643718  0.643909  0.643909
# 67                      TwoLeadECG     0.987345  0.479219  0.987345  0.477616
# 68                             UMD     1.000000  1.000000  1.000000  1.000000
# 69          UWaveGestureLibraryAll     0.575483  0.585520  0.575483  0.390416
# 70            UWaveGestureLibraryX     0.443633  0.394251  0.393982  0.392069
# 71            UWaveGestureLibraryY     0.654621  0.587997  0.654621  0.298078
# 72            UWaveGestureLibraryZ     0.598779  0.601632  0.376806  0.598779
# 73                    WordSynonyms     0.827266  0.819100  0.825855  0.825817
# 74                            Yoga     0.502103  0.991277  0.502103  0.501583
#
#       fluss4    fluss5
# 0   0.457462  0.813429
# 1   0.606020  0.473824
# 2   0.935417  0.938085
# 3   0.489386  0.472810
# 4   0.477778  0.477703
# 5   0.500085  0.653175
# 6   0.949480  0.937797
# 7   1.000000  1.000000
# 8   0.578797  0.578700
# 9   0.641104  0.602186
# 10  0.584778  0.949285
# 11  0.489950  0.476187
# 12  0.349004  0.708784
# 13  0.592347  0.447578
# 14  0.581242  0.217217
# 15  0.128839  0.156819
# 16  0.624429  0.496038
# 17  0.934235  0.432210
# 18  0.650515  0.500614
# 19  1.000000  1.000000
# 20  0.992520  0.968689
# 21  0.987315  0.931390
# 22  0.405706  0.406548
# 23  0.169664  0.169664
# 24  0.167947  0.185458
# 25  0.795767  0.795838
# 26  0.274709  0.392700
# 27  0.557115  0.568719
# 28  0.143285  0.246144
# 29  0.515890  0.513420
# 30  0.250529  0.250529
# 31  1.000000  1.000000
# 32  0.969513  0.962284
# 33  0.425871  0.360752
# 34  0.668998  0.672312
# 35  0.483528  0.543408
# 36  0.960972  0.991332
# 37  0.964806  0.598826
# 38  0.985009  0.985009
# 39  0.761936  0.755316
# 40  0.571606  0.572264
# 41  0.652172  0.636236
# 42  0.588493  0.594242
# 43  0.301442  0.375776
# 44  0.247536  0.479857
# 45  0.617674  0.616446
# 46  1.000000  1.000000
# 47  0.919872  0.920975
# 48  0.337453  0.335282
# 49  0.408487  0.408103
# 50  0.731303  0.731385
# 51  0.720237  0.539712
# 52  0.549792  0.390138
# 53  0.661609  0.686681
# 54  0.547806  0.546527
# 55  0.509502  0.842054
# 56  0.395111  0.395488
# 57  1.000000  1.000000
# 58  0.839204  0.714524
# 59  0.880012  0.808057
# 60  0.474197  0.798308
# 61  0.593571  0.448790
# 62  0.776089  0.570368
# 63  0.392285  0.574965
# 64  0.633871  0.996396
# 65  0.880133  0.990968
# 66  0.643909  0.643909
# 67  0.758329  0.534337
# 68  1.000000  1.000000
# 69  0.199447  0.199588
# 70  0.346977  0.443633
# 71  0.418871  0.556932
# 72  0.232056  0.378681
# 73  0.774295  0.827266
# 74  0.494029  0.502020

# %% [markdown]
# Let's calculate the mean/median/std error.

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: mean_error={np.round(df_scores[name].mean() * 100, 2)}")
# Out:
# flussEnsDil: mean_error=73.64
# fluss1: mean_error=71.78
# fluss2: mean_error=70.53
# fluss3: mean_error=65.06
# fluss4: mean_error=61.53
# fluss5: mean_error=62.25

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: median_error={np.round(df_scores[name].median() * 100, 2)}")
# Out:
# flussEnsDil: median_error=74.57
# fluss1: median_error=72.93
# fluss2: median_error=72.14
# fluss3: median_error=61.65
# fluss4: median_error=59.23
# fluss5: median_error=57.5

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: std_error={np.round(df_scores[name].std() * 100, 2)}")
# Out:
# flussEnsDil: std_error=23.05
# fluss1: std_error=23.93
# fluss2: std_error=24.18
# fluss3: std_error=24.89
# fluss4: std_error=25.34
# fluss5: std_error=24.65

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))
# Out:
# /tmp/ipykernel_55919/3065857076.py:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   ranks = df_scores.rank(1, method = 'min', ascending=False)

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# flussEnsDil:wins=53 rank=1.3
# fluss1:wins=29 rank=2.9
# fluss2:wins=24 rank=2.8
# fluss3:wins=24 rank=3.3
# fluss4:wins=15 rank=3.9
# fluss5:wins=16 rank=3.9

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = orange3score.compute_CD(means, df_scores.shape[0])
orange3score.graph_ranks(avranks=means, names=df_scores.columns[1:], cd=cd, width=5, reverse=True, textspace=1.2, filename="./ranks_known_fixed_target_w.png")

# %%
for name, rank in zip(df_scores.columns[1:], means):
    print(f"{name}: rank={np.round(rank, 5)}")
# Out:
# flussEnsDil: rank=1.29333
# fluss1: rank=2.90667
# fluss2: rank=2.8
# fluss3: rank=3.34667
# fluss4: rank=3.94667
# fluss5: rank=3.90667

# %% [markdown]
# Let's compute wins/losses against the best-ranking algorithm ClaSP.

# %%
# for rival in df_scores.columns[1:]:
#     if rival == "ClaSP": continue
    
#     df_pair = df_scores[["ClaSP", rival]]
#     pair_ranks = df_pair.rank(1, method = 'min', ascending=True)
    
#     wins = pair_ranks[(pair_ranks["ClaSP"] == 1) & (pair_ranks[rival] == 2)].shape[0]
#     losses = pair_ranks[(pair_ranks["ClaSP"] == 2) & (pair_ranks[rival] == 1)].shape[0]
#     ties = pair_ranks[(pair_ranks["ClaSP"] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
#     assert wins + losses + ties == pair_ranks.shape[0]
    
#     print(f"ClaSP vs {rival}: (wins/losses/ties): {wins}/{losses}/{ties}")

# %% [markdown]
# Let's compute wins/losses against the stumpy fluss algorithm (no dilation).

# %%
for rival in df_scores.columns[1:]:
    if rival == "fluss1": continue
    
    df_pair = df_scores[["fluss1", rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=True)
    
    wins = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks["fluss1"] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"fluss1 vs {rival}: (wins/losses/ties): {wins}/{losses}/{ties}")
# Out:
# fluss1 vs flussEnsDil: (wins/losses/ties): 46/22/7
# fluss1 vs fluss2: (wins/losses/ties): 32/32/11
# fluss1 vs fluss3: (wins/losses/ties): 24/42/9
# fluss1 vs fluss4: (wins/losses/ties): 21/45/9
# fluss1 vs fluss5: (wins/losses/ties): 20/47/8

# %%
fontsize = 12
_, ax = plt.subplots(figsize=(5,2))

df_scores.boxplot(ax=ax, rot=30)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

plt.savefig(f"./boxplot_known_fixed_target_w.png", bbox_inches="tight")
# Out:
# /tmp/ipykernel_55919/4256861775.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /tmp/ipykernel_55919/4256861775.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
