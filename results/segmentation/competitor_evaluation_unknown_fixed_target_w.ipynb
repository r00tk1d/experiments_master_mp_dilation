# %% [markdown]
# # Evaluation of the Results for unknown CPs with fixed target range w #
# Notebook from https://github.com/ermshaua/time-series-segmentation-benchmark/blob/main/tssb/notebooks/competitor_evaluation.ipynb. Slightly edited.

# %%
import numpy as np
import pandas as pd

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import sys
sys.path.append("../../")

import orange3score

# %% [markdown]
# Let's load the scores from the different methods.

# %%
df_scores = pd.read_csv("./segmentation_covering_unknown_stumpy_target_w_ensemble.csv")
df_scores
# Out:
#                            dataset  flussEnsDil    fluss1    fluss2    fluss3  \
# 0                            Adiac     0.551136  0.430398  0.479403  0.551136
# 1                        ArrowHead     0.500000  0.994702  0.500000  0.500000
# 2                             Beef     0.939422  0.935417  0.936750  0.939422
# 3                        BeetleFly     0.500000  0.500000  0.500000  0.500000
# 4                      BirdChicken     0.500000  0.500000  0.500000  0.500000
# 5                              CBF     0.256156  0.256156  0.256156  0.256156
# 6                              Car     0.937797  0.861173  0.868268  0.837818
# 7                        Chinatown     1.000000  0.704167  1.000000  1.000000
# 8            ChlorineConcentration     0.577487  0.577487  0.577487  0.577487
# 9                     CinCECGTorso     0.337149  0.337149  0.337149  0.337149
# 10                          Coffee     0.500000  0.899000  0.500000  0.500000
# 11                       Computers     0.500000  0.500000  0.500000  0.500000
# 12                        CricketX     0.202568  0.202568  0.202568  0.202568
# 13                        CricketY     0.201968  0.201968  0.201968  0.201968
# 14                        CricketZ     0.201828  0.201828  0.201828  0.201828
# 15                            Crop     0.125000  0.125000  0.125000  0.125000
# 16             DiatomSizeReduction     0.965233  0.760668  0.779657  0.965233
# 17    DistalPhalanxOutlineAgeGroup     0.935578  0.934235  0.935578  0.935578
# 18                 DistalPhalanxTW     0.474070  0.745266  0.474070  0.474070
# 19                   DodgerLoopDay     1.000000  1.000000  1.000000  1.000000
# 20                          ECG200     0.924541  0.967874  0.924541  0.572200
# 21                     ECGFiveDays     0.523629  0.523629  0.523629  0.523629
# 22             EOGHorizontalSignal     0.256208  0.256208  0.256208  0.256208
# 23               EOGVerticalSignal     0.169664  0.169664  0.169664  0.169664
# 24                         FaceAll     0.142857  0.347546  0.142857  0.142857
# 25                        FaceFour     0.576404  0.576077  0.576077  0.573464
# 26                        FacesUCR     0.805511  0.389634  0.805511  0.151726
# 27                      FiftyWords     0.278047  0.583502  0.278047  0.278047
# 28                            Fish     0.144293  0.144293  0.144293  0.144293
# 29             FreezerRegularTrain     0.260007  0.260007  0.260007  0.260007
# 30                        GunPoint     0.250529  0.250529  0.250529  0.250529
# 31                             Ham     1.000000  1.000000  1.000000  1.000000
# 32                         Haptics     0.500800  0.500800  0.500800  0.500800
# 33                         Herring     0.356421  0.356421  0.356421  0.356421
# 34                     InlineSkate     0.357558  0.357558  0.357558  0.357558
# 35             InsectWingbeatSound     0.250000  0.666406  0.250000  0.250000
# 36                ItalyPowerDemand     0.991332  0.875000  0.875000  0.874378
# 37          LargeKitchenAppliances     0.333333  0.333333  0.333333  0.333333
# 38                      Lightning2     0.555556  0.555556  0.555556  0.555556
# 39                      Lightning7     0.214767  0.214767  0.214767  0.214767
# 40                          Mallat     0.573518  0.563681  0.573518  0.267430
# 41                            Meat     0.663990  0.148214  0.419345  0.663990
# 42                   MedicalImages     0.580065  0.580065  0.580065  0.580065
# 43             MelbournePedestrian     0.148789  0.326735  0.148789  0.148789
# 44    MiddlePhalanxOutlineAgeGroup     0.250152  0.250152  0.250152  0.250152
# 45     MiddlePhalanxOutlineCorrect     0.660609  0.584898  0.660609  0.659211
# 46                 MiddlePhalanxTW     1.000000  1.000000  1.000000  1.000000
# 47                      MoteStrain     0.500000  0.500000  0.500000  0.500000
# 48      NonInvasiveFetalECGThorax1     0.574955  0.452025  0.574955  0.335175
# 49      NonInvasiveFetalECGThorax2     0.408330  0.419134  0.366788  0.397791
# 50                         OSULeaf     0.757315  0.721873  0.689077  0.757112
# 51                        OliveOil     0.365241  0.695048  0.365241  0.365241
# 52                           Plane     0.408730  0.346032  0.408730  0.149751
# 53  ProximalPhalanxOutlineAgeGroup     0.592390  0.629784  0.546557  0.592390
# 54   ProximalPhalanxOutlineCorrect     0.530760  0.486912  0.496731  0.530760
# 55               ProximalPhalanxTW     0.394750  0.496916  0.394750  0.394750
# 56                     ShapeletSim     0.200000  0.752500  0.200000  0.200000
# 57                       ShapesAll     1.000000  1.000000  1.000000  1.000000
# 58           SonyAIBORobotSurface1     0.580000  0.580000  0.580000  0.580000
# 59           SonyAIBORobotSurface2     0.517147  0.517147  0.517147  0.517147
# 60                      Strawberry     0.332323  0.332323  0.332323  0.332323
# 61                     SwedishLeaf     0.251838  0.535262  0.251838  0.251838
# 62                         Symbols     0.296563  0.296563  0.296563  0.296563
# 63                SyntheticControl     0.502381  0.368800  0.502381  0.200000
# 64                ToeSegmentation1     0.500000  0.500000  0.500000  0.500000
# 65                ToeSegmentation2     0.500000  0.500000  0.500000  0.500000
# 66                           Trace     0.733910  0.750372  0.732648  0.683100
# 67                      TwoLeadECG     0.500994  0.500994  0.500994  0.500994
# 68                             UMD     1.000000  1.000000  1.000000  1.000000
# 69          UWaveGestureLibraryAll     0.201058  0.558225  0.201058  0.201058
# 70            UWaveGestureLibraryX     0.201068  0.549161  0.201068  0.201068
# 71            UWaveGestureLibraryY     0.201068  0.201068  0.201068  0.201068
# 72            UWaveGestureLibraryZ     0.201068  0.601632  0.201068  0.201068
# 73                    WordSynonyms     0.726924  0.845824  0.726924  0.726924
# 74                            Yoga     0.503753  0.503753  0.503753  0.503753
#
#       fluss4    fluss5
# 0   0.302734  0.302734
# 1   0.500000  0.500000
# 2   0.935417  0.938085
# 3   0.500000  0.500000
# 4   0.500000  0.500000
# 5   0.256156  0.256156
# 6   0.799780  0.937797
# 7   1.000000  1.000000
# 8   0.577487  0.577487
# 9   0.337149  0.337149
# 10  0.500000  0.500000
# 11  0.500000  0.500000
# 12  0.202568  0.202568
# 13  0.201968  0.201968
# 14  0.201828  0.201828
# 15  0.125000  0.125000
# 16  0.624429  0.342181
# 17  0.668443  0.668443
# 18  0.474070  0.474070
# 19  1.000000  1.000000
# 20  0.572200  0.572200
# 21  0.523629  0.523629
# 22  0.256208  0.256208
# 23  0.169664  0.169664
# 24  0.142857  0.142857
# 25  0.576404  0.281250
# 26  0.151726  0.151726
# 27  0.278047  0.278047
# 28  0.144293  0.144293
# 29  0.260007  0.260007
# 30  0.250529  0.250529
# 31  1.000000  1.000000
# 32  0.500800  0.500800
# 33  0.356421  0.356421
# 34  0.357558  0.357558
# 35  0.250000  0.250000
# 36  0.875000  0.991332
# 37  0.333333  0.333333
# 38  0.555556  0.555556
# 39  0.214767  0.214767
# 40  0.267430  0.267430
# 41  0.333333  0.333333
# 42  0.580065  0.580065
# 43  0.148789  0.148789
# 44  0.250152  0.250152
# 45  0.334137  0.334137
# 46  1.000000  1.000000
# 47  0.500000  0.500000
# 48  0.168958  0.168958
# 49  0.408330  0.145265
# 50  0.757117  0.757315
# 51  0.365241  0.365241
# 52  0.149751  0.149751
# 53  0.376412  0.376412
# 54  0.292460  0.292460
# 55  0.394750  0.394750
# 56  0.200000  0.200000
# 57  1.000000  1.000000
# 58  0.580000  0.580000
# 59  0.517147  0.517147
# 60  0.332323  0.332323
# 61  0.251838  0.251838
# 62  0.296563  0.296563
# 63  0.200000  0.200000
# 64  0.500000  0.500000
# 65  0.500000  0.500000
# 66  0.633382  0.733910
# 67  0.500994  0.500994
# 68  1.000000  1.000000
# 69  0.201058  0.201058
# 70  0.201068  0.201068
# 71  0.201068  0.201068
# 72  0.201068  0.201068
# 73  0.726924  0.726924
# 74  0.503753  0.503753

# %% [markdown]
# Let's calculate the mean/median/std error.

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: mean_error={np.round(df_scores[name].mean() * 100, 2)}")
# Out:
# flussEnsDil: mean_error=49.94
# fluss1: mean_error=53.45
# fluss2: mean_error=48.77
# fluss3: mean_error=46.75
# fluss4: mean_error=43.8
# fluss5: mean_error=43.16

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: median_error={np.round(df_scores[name].median() * 100, 2)}")
# Out:
# flussEnsDil: median_error=50.0
# fluss1: median_error=50.1
# fluss2: median_error=50.0
# fluss3: median_error=50.0
# fluss4: median_error=36.52
# fluss5: median_error=34.22

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: std_error={np.round(df_scores[name].std() * 100, 2)}")
# Out:
# flussEnsDil: std_error=26.48
# fluss1: std_error=24.84
# fluss2: std_error=25.55
# fluss3: std_error=26.1
# fluss4: std_error=24.92
# fluss5: std_error=25.84

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))
# Out:
# /tmp/ipykernel_59709/3065857076.py:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   ranks = df_scores.rank(1, method = 'min', ascending=False)

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# flussEnsDil:wins=56 rank=1.3
# fluss1:wins=58 rank=1.7
# fluss2:wins=47 rank=1.6
# fluss3:wins=46 rank=1.8
# fluss4:wins=41 rank=2.1
# fluss5:wins=43 rank=2.0

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = orange3score.compute_CD(means, df_scores.shape[0])
orange3score.graph_ranks(avranks=means, names=df_scores.columns[1:], cd=cd, width=5, reverse=True, textspace=1.2, filename="./ranks_unknown_fixed_target_w.png")

# %%
for name, rank in zip(df_scores.columns[1:], means):
    print(f"{name}: rank={np.round(rank, 5)}")
# Out:
# flussEnsDil: rank=1.25333
# fluss1: rank=1.66667
# fluss2: rank=1.64
# fluss3: rank=1.78667
# fluss4: rank=2.06667
# fluss5: rank=2.0

# %% [markdown]
# Let's compute wins/losses against the best-ranking algorithm ClaSP.

# %%
# for rival in df_scores.columns[1:]:
#     if rival == "ClaSP": continue
    
#     df_pair = df_scores[["ClaSP", rival]]
#     pair_ranks = df_pair.rank(1, method = 'min', ascending=True)
    
#     wins = pair_ranks[(pair_ranks["ClaSP"] == 1) & (pair_ranks[rival] == 2)].shape[0]
#     losses = pair_ranks[(pair_ranks["ClaSP"] == 2) & (pair_ranks[rival] == 1)].shape[0]
#     ties = pair_ranks[(pair_ranks["ClaSP"] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
#     assert wins + losses + ties == pair_ranks.shape[0]
    
#     print(f"ClaSP vs {rival}: (wins/losses/ties): {wins}/{losses}/{ties}")

# %% [markdown]
# Let's compute wins/losses against the stumpy fluss algorithm (no dilation).

# %%
for rival in df_scores.columns[1:]:
    if rival == "fluss1": continue
    
    df_pair = df_scores[["fluss1", rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=True)
    
    wins = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks["fluss1"] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"fluss1 vs {rival}: (wins/losses/ties): {wins}/{losses}/{ties}")
# Out:
# fluss1 vs flussEnsDil: (wins/losses/ties): 17/19/39
# fluss1 vs fluss2: (wins/losses/ties): 14/20/41
# fluss1 vs fluss3: (wins/losses/ties): 9/27/39
# fluss1 vs fluss4: (wins/losses/ties): 4/30/41
# fluss1 vs fluss5: (wins/losses/ties): 6/30/39

# %%
fontsize = 12
_, ax = plt.subplots(figsize=(5,2))

df_scores.boxplot(ax=ax, rot=30)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

plt.savefig(f"./boxplot_unknown_fixed_target_w.png", bbox_inches="tight")
# Out:
# /tmp/ipykernel_59709/197214802.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /tmp/ipykernel_59709/197214802.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
