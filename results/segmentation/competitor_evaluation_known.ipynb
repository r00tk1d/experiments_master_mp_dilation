# %% [markdown]
# # Evaluation of the Results for known CPs #
# Notebook from https://github.com/ermshaua/time-series-segmentation-benchmark/blob/main/tssb/notebooks/competitor_evaluation.ipynb. Slightly edited.

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../../")

from tqdm import tqdm

# %% [markdown]
# Let's load the scores from the different methods.

# %%
df_scores = pd.read_csv("./segmentation_covering_known_stumpy.csv")
df_scores
# Out:
#                            dataset  ESPRESSO   BOCD  Window  BinSeg  FLOSS  \
# 0                            Adiac     0.421  0.303   0.608   0.948  0.971
# 1                        ArrowHead     0.480  0.500   0.913   0.991  0.995
# 2                             Beef     0.482  0.804   0.736   0.692  0.935
# 3                        BeetleFly     0.541  0.802   0.495   0.652  0.968
# 4                      BirdChicken     0.505  0.485   0.925   0.469  0.478
# 5                              CBF     0.435  0.619   0.717   0.357  0.940
# 6                              Car     0.293  0.256   0.528   0.793  0.764
# 7                        Chinatown     1.000  1.000   1.000   1.000  1.000
# 8            ChlorineConcentration     0.555  0.836   0.744   0.530  1.000
# 9                     CinCECGTorso     0.474  0.593   0.569   0.645  0.676
# 10                          Coffee     0.524  0.492   0.591   0.817  0.988
# 11                       Computers     0.499  0.938   0.841   0.950  0.494
# 12                        CricketX     0.278  0.203   0.479   0.710  0.787
# 13                        CricketY     0.246  0.208   0.515   0.891  0.564
# 14                        CricketZ     0.235  0.201   0.548   0.687  0.733
# 15                            Crop     0.287  0.244   0.543   0.987  0.248
# 16             DiatomSizeReduction     0.522  0.332   0.543   0.949  0.964
# 17    DistalPhalanxOutlineAgeGroup     0.739  0.668   0.573   0.894  0.934
# 18                 DistalPhalanxTW     0.752  0.474   0.520   0.829  0.745
# 19                   DodgerLoopDay     1.000  1.000   1.000   1.000  1.000
# 20                          ECG200     0.654  0.572   0.734   0.983  0.968
# 21                     ECGFiveDays     0.732  0.523   0.726   0.495  0.970
# 22             EOGHorizontalSignal     0.373  0.962   0.638   0.623  0.408
# 23               EOGVerticalSignal     0.360  0.578   0.510   0.661  0.342
# 24                         FaceAll     0.171  0.266   0.651   0.702  0.399
# 25                        FaceFour     0.532  0.490   0.377   0.597  0.795
# 26                        FacesUCR     0.224  0.183   0.482   0.725  0.653
# 27                      FiftyWords     0.262  0.525   0.527   0.951  0.571
# 28                            Fish     0.219  0.263   0.561   0.636  0.288
# 29             FreezerRegularTrain     0.274  0.707   0.571   0.677  0.519
# 30                        GunPoint     0.482  0.478   0.811   0.733  0.988
# 31                             Ham     0.251  0.261   0.615   0.558  0.251
# 32                         Haptics     0.424  0.542   0.598   0.726  0.380
# 33                         Herring     1.000  1.000   1.000   1.000  1.000
# 34                     InlineSkate     0.332  0.494   0.587   0.564  0.579
# 35             InsectWingbeatSound     0.249  0.250   0.513   0.985  0.690
# 36                ItalyPowerDemand     0.482  0.500   0.751   0.993  0.975
# 37          LargeKitchenAppliances     0.326  0.354   0.505   0.670  0.923
# 38                      Lightning2     0.913  0.556   0.822   0.440  0.688
# 39                      Lightning7     0.358  0.422   0.535   0.388  0.765
# 56  1.000  0.785981  0.378988  0.580513  0.395111  0.395488
# 57  0.984  1.000000  1.000000  1.000000  1.000000  1.000000
# 58  0.990  0.973115  0.970315  0.982961  0.839204  0.714524
# 59  0.979  0.985277  0.837189  0.498529  0.880012  0.808057
# 60  0.695  0.470744  0.472533  0.450605  0.474197  0.798308
# 61  0.997  0.500668  0.983202  0.495117  0.593571  0.448790
# 62  0.978  0.512736  0.514013  0.830111  0.776089  0.570368
# 63  0.990  0.579710  0.582792  0.394099  0.392285  0.574965
# 64  1.000  0.993523  0.997116  0.884613  0.633871  0.996396
# 65  0.997  0.989684  0.989043  0.994829  0.880133  0.990968
# 66  0.896  0.643718  0.643909  0.643909  0.643909  0.643909
# 67  0.996  0.479219  0.987345  0.477616  0.758329  0.534337
# 68  1.000  1.000000  1.000000  1.000000  1.000000  1.000000
# 69  0.992  0.585520  0.575483  0.390416  0.199447  0.199588
# 70  0.987  0.394251  0.393982  0.392069  0.346977  0.443633
# 71  0.963  0.587997  0.654621  0.298078  0.418871  0.556932
# 72  0.873  0.601632  0.376806  0.598779  0.232056  0.378681
# 73  0.995  0.819100  0.825855  0.825817  0.774295  0.827266
# 74  0.995  0.991277  0.502103  0.501583  0.494029  0.502020

# %% [markdown]
# Let's calculate the mean/median/std error.

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: mean_error={np.round(df_scores[name].mean() * 100, 2)}")
# Out:
# ESPRESSO: mean_error=46.14
# BOCD: mean_error=49.36
# Window: mean_error=63.87
# BinSeg: mean_error=77.51
# FLOSS: mean_error=71.79
# ClaSP: mean_error=93.07
# fluss1: mean_error=71.78
# fluss2: mean_error=70.53
# fluss3: mean_error=65.06
# fluss4: mean_error=61.53
# fluss5: mean_error=62.25

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: mean_error={np.round(df_scores[name].median() * 100, 2)}")
# Out:
# ESPRESSO: mean_error=42.1
# BOCD: mean_error=49.2
# Window: mean_error=59.1
# BinSeg: mean_error=79.3
# FLOSS: mean_error=72.9
# ClaSP: mean_error=98.4
# fluss1: mean_error=72.93
# fluss2: mean_error=72.14
# fluss3: mean_error=61.65
# fluss4: mean_error=59.23
# fluss5: mean_error=57.5

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: std_error={np.round(df_scores[name].std() * 100, 2)}")
# Out:
# ESPRESSO: std_error=22.07
# BOCD: std_error=24.13
# Window: std_error=17.26
# BinSeg: std_error=18.97
# FLOSS: std_error=23.93
# ClaSP: std_error=11.31
# fluss1: std_error=23.93
# fluss2: std_error=24.18
# fluss3: std_error=24.89
# fluss4: std_error=25.34
# fluss5: std_error=24.65

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))
# Out:
# /tmp/ipykernel_9400/3065857076.py:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   ranks = df_scores.rank(1, method = 'min', ascending=False)

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# ESPRESSO:wins=6 rank=8.7
# BOCD:wins=7 rank=8.2
# Window:wins=8 rank=6.2
# BinSeg:wins=14 rank=4.4
# FLOSS:wins=7 rank=4.6
# ClaSP:wins=50 rank=2.1
# fluss1:wins=6 rank=4.7
# fluss2:wins=11 rank=4.7
# fluss3:wins=10 rank=5.7
# fluss4:wins=9 rank=6.2
# fluss5:wins=9 rank=6.2

# %% [markdown]
# Let's plot and output the ranks.

# %%
# cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
# Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, width=5, reverse=True, textspace=1.2, filename="../ranks.png")

# compute_CD not working with newest Orange version

# %%
for name, rank in zip(df_scores.columns[1:], means):
    print(f"{name}: rank={np.round(rank, 5)}")
# Out:
# ESPRESSO: rank=8.66667
# BOCD: rank=8.2
# Window: rank=6.22667
# BinSeg: rank=4.42667
# FLOSS: rank=4.64
# ClaSP: rank=2.08
# fluss1: rank=4.73333
# fluss2: rank=4.73333
# fluss3: rank=5.68
# fluss4: rank=6.2
# fluss5: rank=6.24

# %% [markdown]
# Let's compute wins/losses against the best-ranking algorithm ClaSP.

# %%
for rival in df_scores.columns[1:]:
    if rival == "ClaSP": continue
    
    df_pair = df_scores[["ClaSP", rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=True)
    
    wins = pair_ranks[(pair_ranks["ClaSP"] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks["ClaSP"] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks["ClaSP"] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"ClaSP vs {rival}: (wins/losses/ties): {wins}/{losses}/{ties}")
# Out:
# ClaSP vs ESPRESSO: (wins/losses/ties): 1/68/6
# ClaSP vs BOCD: (wins/losses/ties): 3/66/6
# ClaSP vs Window: (wins/losses/ties): 2/67/6
# ClaSP vs BinSeg: (wins/losses/ties): 11/57/7
# ClaSP vs FLOSS: (wins/losses/ties): 9/59/7
# ClaSP vs fluss1: (wins/losses/ties): 12/59/4
# ClaSP vs fluss2: (wins/losses/ties): 11/60/4
# ClaSP vs fluss3: (wins/losses/ties): 10/61/4
# ClaSP vs fluss4: (wins/losses/ties): 12/59/4
# ClaSP vs fluss5: (wins/losses/ties): 10/61/4

# %% [markdown]
# Let's compute wins/losses against the stumpy fluss algorithm (no dilation).

# %%
for rival in df_scores.columns[1:]:
    if rival == "fluss1": continue
    
    df_pair = df_scores[["fluss1", rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=True)
    
    wins = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks["fluss1"] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"fluss1 vs {rival}: (wins/losses/ties): {wins}/{losses}/{ties}")
# Out:
# fluss1 vs ESPRESSO: (wins/losses/ties): 11/60/4
# fluss1 vs BOCD: (wins/losses/ties): 12/59/4
# fluss1 vs Window: (wins/losses/ties): 25/46/4
# fluss1 vs BinSeg: (wins/losses/ties): 37/34/4
# fluss1 vs FLOSS: (wins/losses/ties): 39/32/4
# fluss1 vs ClaSP: (wins/losses/ties): 59/12/4
# fluss1 vs fluss2: (wins/losses/ties): 32/32/11
# fluss1 vs fluss3: (wins/losses/ties): 24/42/9
# fluss1 vs fluss4: (wins/losses/ties): 21/45/9
# fluss1 vs fluss5: (wins/losses/ties): 20/47/8

# %%
fontsize = 12
_, ax = plt.subplots(figsize=(5,2))

df_scores.boxplot(ax=ax, rot=30)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

plt.savefig(f"./boxplot_known.png", bbox_inches="tight")
# Out:
# /tmp/ipykernel_9400/1288902110.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /tmp/ipykernel_9400/1288902110.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
