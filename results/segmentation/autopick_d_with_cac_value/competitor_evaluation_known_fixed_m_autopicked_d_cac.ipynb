# %% [markdown]
# # Evaluation of the Results for known CPs with fixed window size m (number of values) #
# Notebook from https://github.com/ermshaua/time-series-segmentation-benchmark/blob/main/tssb/notebooks/competitor_evaluation.ipynb. Slightly edited.

# %%
import numpy as np
import pandas as pd

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import sys
sys.path.append("../../")

import orange3score

# %% [markdown]
# Let's load the scores from the different methods.

# %%
df_scores = pd.read_csv("./segmentation_covering_known_stumpy_m_ensemble_learned.csv")
df_scores = df_scores.iloc[:, [0,1,2,3,4,5,6,7]]
df_scores
# Out:
#                            dataset  flussEnsDil    fluss1    fluss2    fluss3  \
# 0                            Adiac     0.903707  0.970755  0.903707  0.800740
# 1                        ArrowHead     0.985497  0.994702  0.980274  0.985497
# 2                             Beef     0.934085  0.935417  0.934085  0.768329
# 3                        BeetleFly     0.996880  0.967709  0.996880  0.663053
# 4                      BirdChicken     0.980656  0.477703  0.973781  0.980656
# 5                              CBF     0.736472  0.764311  0.736472  0.498540
# 6                              Car     0.874664  0.939744  0.874664  0.686785
# 7                        Chinatown     1.000000  1.000000  1.000000  1.000000
# 8            ChlorineConcentration     0.999744  0.999744  0.999744  0.998463
# 9                     CinCECGTorso     0.681064  0.675982  0.664521  0.681064
# 10                          Coffee     0.988071  0.988071  0.988071  0.982159
# 11                       Computers     0.942118  0.493516  0.941950  0.942118
# 12                        CricketX     0.591978  0.787400  0.565347  0.591978
# 13                        CricketY     0.556824  0.563786  0.396634  0.394884
# 14                        CricketZ     0.767395  0.733173  0.560261  0.767395
# 15                            Crop     0.334651  0.247633  0.243074  0.334651
# 16             DiatomSizeReduction     0.971117  0.963736  0.505209  0.971117
# 17    DistalPhalanxOutlineAgeGroup     0.931551  0.934235  0.931551  0.931551
# 18                 DistalPhalanxTW     0.749414  0.745266  0.722943  0.669960
# 19                   DodgerLoopDay     1.000000  1.000000  1.000000  1.000000
# 20                          ECG200     0.967060  0.967874  0.956518  0.951679
# 21                     ECGFiveDays     0.972355  0.969889  0.955243  0.908181
# 22             EOGHorizontalSignal     0.417223  0.407675  0.408494  0.408092
# 23               EOGVerticalSignal     0.335479  0.340074  0.333071  0.333318
# 24                         FaceAll     0.547511  0.399217  0.405082  0.547511
# 25                        FaceFour     0.787800  0.795087  0.541790  0.537905
# 26                        FacesUCR     0.668269  0.652956  0.668269  0.466049
# 27                      FiftyWords     0.570516  0.571349  0.570516  0.569235
# 28                            Fish     0.537034  0.288193  0.428884  0.440206
# 29             FreezerRegularTrain     0.515706  0.519049  0.515706  0.466347
# 30                        GunPoint     0.250529  0.250529  0.250529  0.250529
# 31                             Ham     1.000000  1.000000  1.000000  1.000000
# 32                         Haptics     0.987278  0.988332  0.987278  0.954080
# 33                         Herring     0.583670  0.379821  0.583670  0.530521
# 34                     InlineSkate     0.591667  0.579493  0.575577  0.591667
# 35             InsectWingbeatSound     0.702764  0.689978  0.702764  0.695804
# %%
for name in df_scores.columns[1:]:
    print(f"{name}: mean_error={np.round(df_scores[name].mean() * 100, 2)}")
# Out:
# flussEnsDil: mean_error=76.25
# fluss1: mean_error=71.78
# fluss2: mean_error=72.3
# fluss3: mean_error=70.55
# fluss4: mean_error=66.79
# fluss5: mean_error=67.06
# flussDilationLearned: mean_error=70.55

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: median_error={np.round(df_scores[name].median() * 100, 2)}")
# Out:
# flussEnsDil: median_error=77.2
# fluss1: median_error=72.93
# fluss2: median_error=72.29
# fluss3: median_error=67.0
# fluss4: median_error=61.21
# fluss5: median_error=61.64
# flussDilationLearned: median_error=68.68

# %%
for name in df_scores.columns[1:]:
    print(f"{name}: std_error={np.round(df_scores[name].std() * 100, 2)}")
# Out:
# flussEnsDil: std_error=21.58
# fluss1: std_error=23.93
# fluss2: std_error=23.69
# fluss3: std_error=22.92
# fluss4: std_error=23.52
# fluss5: std_error=23.86
# flussDilationLearned: std_error=23.61

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))
# Out:
# /tmp/ipykernel_54974/3065857076.py:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   ranks = df_scores.rank(1, method = 'min', ascending=False)

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# flussEnsDil:wins=47 rank=1.4
# fluss1:wins=38 rank=3.0
# fluss2:wins=18 rank=3.3
# fluss3:wins=19 rank=3.9
# fluss4:wins=17 rank=4.2
# fluss5:wins=16 rank=4.4
# flussDilationLearned:wins=17 rank=3.4

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = orange3score.compute_CD(means, df_scores.shape[0])
orange3score.graph_ranks(avranks=means, names=df_scores.columns[1:], cd=cd, width=5, reverse=True, textspace=1.2, filename="./ranks_known_fixed_m_ensemble_learned.png")

# %%
for name, rank in zip(df_scores.columns[1:], means):
    print(f"{name}: rank={np.round(rank, 5)}")
# Out:
# flussEnsDil: rank=1.44
# fluss1: rank=2.98667
# fluss2: rank=3.32
# fluss3: rank=3.94667
# fluss4: rank=4.22667
# fluss5: rank=4.36
# flussDilationLearned: rank=3.4

# %% [markdown]
# Let's compute wins/losses against the stumpy fluss algorithm (no dilation).

# %%
for rival in df_scores.columns[1:]:
    if rival == "fluss1": continue
    
    df_pair = df_scores[["fluss1", rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=True)
    
    wins = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks["fluss1"] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks["fluss1"] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"fluss1 vs {rival}: (wins/losses/ties): {wins}/{losses}/{ties}")
# Out:
# fluss1 vs flussEnsDil: (wins/losses/ties): 37/28/10
# fluss1 vs fluss2: (wins/losses/ties): 25/40/10
# fluss1 vs fluss3: (wins/losses/ties): 24/44/7
# fluss1 vs fluss4: (wins/losses/ties): 22/46/7
# fluss1 vs fluss5: (wins/losses/ties): 23/45/7
# fluss1 vs flussDilationLearned: (wins/losses/ties): 18/32/25

# %%
fontsize = 12
_, ax = plt.subplots(figsize=(5,2))

df_scores.boxplot(ax=ax, rot=30)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

plt.savefig(f"./boxplot_known_fixed_m_ensemble_learned.png", bbox_inches="tight")
# Out:
# /tmp/ipykernel_54974/401338553.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /tmp/ipykernel_54974/401338553.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
